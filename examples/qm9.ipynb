# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molmetrics as mm
import matplotlib.pyplot as plt
import lovelyplots

plt.style.use("ipynb")

# %%
mols = mm.RDKitMolecules.from_directory("../tests/data/qm9")
mols = mols.add_bonds()

# %%
mols[0]

# %%
mols[1]

# %%
mols.validity(), mols.uniqueness()

# %%
from molmetrics.datatypes import Bond, Atom

# %%
print(Bond(Atom("C"), Atom("C"), 1.0))

# %%
bond_lengths = mols.bond_lengths()
for bond, lengths in bond_lengths.items():
    plt.hist(lengths, bins=20)
    plt.title(f"{bond[0].symbol}-{bond[1].symbol} Bond Lengths")
    plt.show()

# %%
mols.posebusters_analysis()

# %%
mols.local_environments()

# %%
bispectra = mols.local_environment_bispectra().aggregate_by_local_environment()
for env in bispectra:
    plt.imshow(bispectra[env])
    plt.title(f"Bispectrum for {env}")
    plt.show()
