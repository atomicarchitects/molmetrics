# %%
import molecular_metrics as mm

# %%
mols = mm.RDKitMolecules.from_directory('tests/data')
mols = mols.add_bonds()

# %%
mols[0]

# %%
mols[1]

# %%
mols.validity(), mols.uniqueness()
# Out:
# (1.0, 1.0)
